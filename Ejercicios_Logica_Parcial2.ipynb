# %% [markdown]
# <a href="https://colab.research.google.com/github/CamilaNanini/LogicaFamaf2025/blob/main/Ejercicios_Logica_Parcial2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##(1) De una prueba elemental de reticulados cuaterna de la sentencia elemental pura: ∀x∀y∀z ((x i y) i z = x i (y i z)) ##

# %% [markdown]
# Como tenemos la propiedad x ≤ y y y ≤ x implican x = y, cualesquiera sean x, y ∈ L entonces podemos demostrar que (xiy)iz≤xi(yiz) y xi(yiz)≤(xiy)iz lo que implicaria que xi(yiz)=(xiy)iz.
#
# Tomemos un a,b,c en L arbitrarios y fijos, e instanciemos x=a, y=b , z=c
#
# **Demostración de la primera desigualdad**
#
# Tomemos (aib)ic como hipótesis
#
# Por el axioma (6, AiesC): (aib)ic≤(aib) y (aib)ic≤c
#
# Como además (usando de nuevo AiesC) (aib)≤b y (aib)≤a, entonces al final tenemos: (aib)ic≤b,(aib)ic≤a,(aib)ic≤c.
#
# En particular: (aib)ic≤b y (aib)ic≤c.
#
# Entonces, por el axioma (7, Ai≥C), (aib)ic≤bic.
#
# Como además  (aib)ic≤a, juntamos esto con (aib)ic≤(bic).
#
# De nuevo, por (7, Ai≥C): **(aib)ic≤ai(bic)**
#
# **Demostración de la segunda desigualdad**
#
# Tomemos ahora ai(bic) como hipótesis
#
# Por el axioma (6, AiesC): ai(bic)≤a y ai(bic)≤(bic)
#
# A su vez, de ai(bic)≤(bic), se sigue que: ai(bic)≤y y ai(bic)≤c
#
# Entonces tenemos: ai(bic)≤a,ai(bic)≤b,ai(bic)≤c.
#
# En particular: ai(bic)≤(aib) (por el axioma (7))
#
# Ahora: ai(bic)≤(aib) y ai(bic)≤c.
#
# Entonces, de nuevo por (7,Ai≥C): ai(bic)≤(aib)ic
#
# Por Antisimetría: (aib)ic=ai(bic).
#
# Como a,b,c eran arbitrarios entonces vale para todos los elementos de L

# %% [markdown]
# ##(2) De una prueba elemental de reticulados cuaterna de la sentencia elemental pura: ∀x∀y∀z∀w((x ≤ z ∧ y ≤ w) → (x s y ≤ z s w)) ##

# %% [markdown]
# Sean a,b,c,d∈L arbitrarios y supongamos la hipótesis x≤z y y≤w, instanciando x=a,y=b,z=c y w=d. Entonces tenemos a≤c y b≤d y queremos probar asb≤csd.
#
# Por AsesC aplicada a c y d obtenemos c≤csd y d≤csd.
#
# Dado que a≤c (hipótesis) y c≤csd (paso 1), por A≤T (axioma (2)) deducimos a≤csd.
#
# Análogamente, b≤d (hipótesis) y d≤csd (paso 1) implican por transitividad b≤csd.
#
# Ahora b≤csd y a≤csd. Aplicando As≤C (axioma (5)) con u:=a,v:=b,t:=csd obtenemos asb≤csd.
#
# Así, a partir de a≤c y b≤d llegamos a asb≤csd. Como a,b,c,d eran arbitrarios, hemos demostrado la sentencia ∀x∀y∀z∀w((x≤z∧y≤w)→xsy≤zsw).

# %% [markdown]
# ##(3) De una prueba elemental de reticulados cuaterna de la sentencia elemental pura: ∀x∀y∀z (x s (y i z) ≤ (x s y) i (x s z)) ##

# %% [markdown]
# AsesC: ∀u∀v(u≤usv∧v≤usv).
#
# As≤C: ∀u∀v∀t((u≤t∧v≤t)→usv≤t).
#
# AiesC: ∀u∀v(uiv≤u∧uiv≤v).
#
# Ai≥C: ∀u∀v∀t((t≤u∧t≤v)→t≤uiv).
#
# Transitiv.: ∀u∀v∀w((u≤v∧v≤w)→u≤w)
#
# **Demostracion**
#
# Sean a,b,c∈L arbitrarios. Queremos probar as(bic)≤(asb)i(asc).
#
# Por AsesC aplicada a a,b obtenemos b≤asb.
#
# Por AiesC aplicada a b,c obtenemos bic≤b.
#
# De (2) y (1), por A≤T (transitividad), se sigue bic≤asb.
#
# Ahora aplicamos As≤C con u:=a,v:=bic,t:=asb. Como a≤asb (paso 1) y bic≤asb (paso 3), por As≤C concluimos as(bic)≤asb.
#
# Análogamente por AsesC: a≤asc, por AiesC: bic≤c, por transitividad: bic≤asc, por As≤C con u:=a,v:=bic,t:=asc obtenemos as(bic)≤asc.
#
# Ahora tenemos que: as(bic)≤asb y as(bic)≤asc.
#
# Aplicando Ai≥C con u:=asb,v:=asc,t:=as(bic) deducimos as(bic)≤(asb)i(asc).
#
# Como a,b,c eran arbitrarios, hemos probado la sentencia para todos los elementos de L.

# %% [markdown]
# ##(4) De una prueba elemental de reticulados cuaterna de la sentencia elemental pura: ∀x∀y(x ≤ y ↔ x i y = x) ##

# %% [markdown]
# A≤R: ∀x(x≤x).
#
# A≤A (antisimetría): ∀x∀y((x≤y∧y≤x)→x=y).
#
# AiesC: ∀x∀y(xiy≤x ∧ xiy≤y).
#
# Ai≥C: ∀x∀y∀z((z≤x∧z≤y)→z≤xiy).
#
# Queremos probar: ∀x∀y(x≤y⟺xiy=x).
#
# Para eso probamos las dos implicaciones tomando a,b arbitrarios.
#
# **Prueba de (a≤b)⇒aib=a**
#
# 1. Por A≤R, a≤a.
# 2. Supongamos a≤b (hipótesis).
# 3. De 1. y 2., por Ai≥C (tomando z:=a,x:=a,y:=b) se obtiene a≤aib.
# 4. Por AiesC, aib≤a.
# 5. De 3 y 4, por antisimetría (A≤A) concluimos aib=a.
#
# Así queda probada la primera implicación.
#
# **Prueba de aib=a⇒(a≤b)**
#
# 1. Supongamos aib=a.
# 2. Por AiesC sabemos aib≤b.
# 3. Reemplazando aib por a en 2. (usando la igualdad de 1) obtenemos a≤b.
#
# Así queda probada la segunda implicación.
#
# **Conclusión**
#
# Dado que a,b eran arbitrarios, hemos mostrado ∀x∀y(x≤y⟺xiy=x)

# %% [markdown]
# ##(5) De una prueba elemental de reticulados cuaterna de la sentencia elemental pura: ∀x (¬∃z(x ≤ z ∧ ¬(z = x)) → ∀z(z ≤ x)) ##

# %% [markdown]
# Tomemos a,b,c elementos arbitrarios
#
# **Prueba**
#
# Sea a arbitrario. Supongamos la hipótesis: ¬∃z(a≤z∧¬(z=a)).
#
# Queremos probar ∀z(z≤a).
#
# Sea c arbitrario. Es suficiente probar c≤a.
#
# Aplicando AsesC a los elementos a y c obtenemos a≤ascyc≤asc.
#
# Consideremos el elemento asc. Si fuera distinto de a, entonces se tendría a≤asc y ¬(asc=a), lo cual equivaldría exactamente a la existencia de un z (concretamente z:=asc) tal que a≤z y ¬(z=a).
#
# Es decir, la afirmación a≤asc ∧ ¬(asc=a) implicaría ∃z(a≤z∧¬(z=a)).
#
# Pero H afirma la negación de esa existencia. Por tanto la suposición del paso 4 no puede ocurrir. Como por AsesC sabemos a≤asc, la única manera de evitar la contradicción con H es que asc=a.
#
# Usando c≤asc (del paso 3) y la igualdad asc=a (del paso 5) concluimos c≤a.
#
# Dado que c era arbitrario, acabamos de probar la sentencia: ∀z(z≤a).
#
# Como a también era arbitrario, hemos demostrado la sentencia universal: ∀a(¬∃z(a≤z∧¬(z=a))→∀z(z≤a)).

# %% [markdown]
# ##(6) De una prueba elemental de reticulados cuaterna de la sentencia elemental pura: ∀x (¬∃z(z ≤ x ∧ ¬(z = x)) → ∀z(x ≤ z)) ##

# %% [markdown]
# Sea a arbitrario. Supongamos la hipótesis:¬∃z(z≤a∧¬(z=a)).
#
# Queremos probar ∀z(a≤z).
#
# Sea c arbitrario. Basta probar a≤c.
#
# Consideremos el elemento aic. Por AiesC sabemos aic≤a y aic≤c.
#
# Si aic fuera distinto de a, entonces existiría un elemento z (concretamente z:=aic) tal que z≤a y ¬(z=a). Es decir, aic≤a ∧ ¬(aic=a) ⟹ ∃z(z≤a∧¬(z=a)), lo cual contradice H.
#
# Por tanto la única posibilidad compatible con H y con aic≤a es aic=a.
#
# De aic≤c y de la igualdad aic=a se sigue que a≤c.
#
# Como c era arbitrario, hemos probado ∀z(a≤z).
#
# Dado que a era arbitrario, concluimos la sentencia universal: ∀a(¬∃z(z≤a∧¬(z=a))→∀z(a≤z)).

# %% [markdown]
# ##(7) Consideremos el siguiente resultado: Sea (L,s, i, ≤) un reticulado cuaterna. Si x, y ∈ L son tales que y tapa a x, entonces para cualquier u ∈ L, se tiene que si u ≰ x, entonces x s u = y s u. ##
# (a) De una sentencia elemental pura φ de reticulados cuaterna la cual
# exprese este resultado.
# (b) De una prueba elemental de reticulados cuaterna de la sentencia φ.

# %% [markdown]
# **TAPA:** Dado un poset (P, ≤) y x, y ∈ P diremos que y tapa x o que x es tapado por y cuando se de que x < y y y ≤ z, para cada z ∈ P tal que x < z.
# O sea: (x<y)∧(∀z∈P)(x<z→y≤z)
#
# a) φ=∀x∀y((x≤y ∧ ¬(x=y) ∧ ∀z((x≤z ∧ ¬(x=z)) → y≤z)) → ∀u((¬(u≤x))→(xsu=ysu)))
# es la sentencia elemental pura.
# Donde (x≤y ∧ ¬(x=y) ∧ ∀z((x≤z ∧ ¬(x=z)) → y≤z)) es lo de tapa.
#
# b) Tomemos elementos arbitrarios a,b,c∈L (x=a , y=b y u=c)y supongamos las hipótesis:
#
# (H1) a≤b y ¬(a=b).
#
# (H2) ∀z((a≤z ∧ ¬(a=z))→b≤z)
#
# (H3) ¬(c≤a)
#
# Usando antisimetria habria que probar el menor o igual de cada lado
#
# **Probar asc≤bsc**
#
# Por AsesC (instanciación con a,c): a≤asc y c≤asc. (AsesC con a,c).
#
# Por AsesC (instanciación con b,c):
# b≤bsc y c≤bsc. (AsesC con b,c).
#
# De (H1) a≤b y de 2) b≤bsc, por A≤T (transitividad) deducimos: a≤bsc. (A≤T).
#
# De 2) tenemos también c≤bsc. Juntando a≤bsc y c≤bsc, por As≤C deducimos: asc≤bsc.
#
# **Probar bsc≤asc**
#
# Repetimos la parte útil de 1): por AsesC con a,c tenemos a≤asc y c≤asc. (AsesC con a,c).
#
# Si se diera a=asc, entonces de c≤asc seguiría c≤a, contradiciendo (H3). Por tanto no puede ocurrir a=asc. Entonces ¬(a=asc) (contradicción con (H3)).
#
# De 5) y 6) concluimos a<asc (es decir,a≤asc y son distintos) (definición de <).
#
# Aplicando la hipótesis de tapa (H2) con z:=asc: dado que a<asc, se obtiene b≤asc. (H2 con z=asc).
#
# De 5) tenemos c≤asc. Juntando b≤asc y c≤asc, por As≤C deducimos: bsc≤asc.

# %% [markdown]
# ##(8) De una sentencia elemental pura de posets la cual sea verdadera en un poset (P, ≤) si y solo si (P, ≤) es un reticulado par cuyo reticulado terna asociado es distributivo. ##

# %% [markdown]
# Recordar que la distibutividad en ternas es: Dis1 x i (y s z) = (x i y) s (x i z), cualesquiera sean x, y, z ∈ L
#
# Definiciones auxiliares (fórmulas puras):
#
# Sup(u;x,y) (u es supremo de x,y): (x≤u ∧ y≤u) ∧ ∀w((x≤w ∧ y≤w) → u≤w).
#
# Inf(v;x,y) (v es ínfimo de x,y): (v≤x ∧ v≤y) ∧ ∀w((w≤x ∧ w≤y) → w≤v).
#
# Ahora la sentencia pura:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## (9) De una formula elemental pura φ de posets la cual tenga a x como su unica variable libre y la cual cumpla: ##
#
# (a) φ es verdadera en ({1, 2, 3, 9, 10, 14, 20}, |) cuando le asignamos a x el
# elemento e ∈ {1, 2, 3, 9, 10, 14, 20} si y solo si e = 14

# %% [markdown]
# "z cubre a y": cov(z,y):⟺ y<z ∧ ¬∃w (y<w∧w<z).
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## (10) De una sentencia elemental pura de reticulados acotados la cual sea verdadera en un reticulado acotado (L,s, i, 0, 1) si y solo si el reticulado acotado ({1, 3, 5, 15, 30}, mcm, mcd, 1, 30) es isomorfo a un subreticulado acotado de (L,s, i, 0, 1) ##

# %% [markdown]
# En palbras es: Existen 3 elementos (a,b,c) tales que son distintos entre si y distintos de 1 y 0, y asb=c aib=0 y cs1=1

# %% [markdown]
# ## (11) De una prueba elemental de posets de la sentencia elemental pura de posets: (∀x∃y(¬(x = y) ∧ x ≤ y) → ∃x∃y∃z(¬(x = y) ∧ ¬(x = z) ∧ ¬(y = z))) ##

# %% [markdown]
# Axiomas elementales de posets.
#
# (1) ∀x(x ≤ x)
#
# (2) ∀x∀y∀z((x ≤ y ∧ y ≤ z) → x ≤ z)
#
# (3) ∀x∀y((x ≤ y ∧ y ≤ x) → x = y)
#
# **Prueba**
#
# 1. Supongamos la hipótesis
# 2. Sea a un elemento arbitrario con x:=a obtenemos: ∃y(¬(a=y)∧a≤y) (2)
# 3. Llamemos b a un elemento tal que ¬(a=b)ya≤b (3)
# 4. Ahora usamos H con x:=b y obtenemos: ∃z(¬(b=z)∧b≤z) (4)
# 5. Llamemos c a un elemento tal que ¬(b=c) y b≤c (5)
#
# Hasta ahora tenemos:
#
# ¬(a=b) y ¬(b=c)
#
# 6. Queremos probar ¬(a=c), lo vamos a hacer por absurdo
# *   Suponemos a=c
# *   De b≤c (5) y c=a --> b≤a.
# *   Tenemos también a≤b (3). Entonces por axioma 3 de los axiomas elementales de posets se da que a=b
# *   Absurdo con ¬(a=b) (3).
#
# 7. Ahora podemos hacer la conjunción Formamos la conjunción ¬(a=b)∧¬(a=c)∧¬(b=c).
#
# 8. Ahora aplicamos los cuantificadores con los testigos a,b,c obtenemos primero
#
# ∃z(¬(a=b)∧¬(a=z)∧¬(b=z))
#
# (con z:=c), luego
#
# ∃y∃z(¬(x=y)∧¬(x=z)∧¬(y=z))
#
# (con x:=a, y:=b), y finalmente
#
# ∃x∃y∃z(¬(x=y)∧¬(x=z)∧¬(y=z))

# %% [markdown]
# ## (13) Sean Dis1 = ∀x∀y∀z(x i (y s z) = (x i y) s (x i z)) Dis2 = ∀x∀y∀z(x s (y i z) = (x s y) i (x s z)). De una prueba elemental de reticulados terna de la sentencia (Dis2 → Dis1). ##

# %% [markdown]
# Axiomas elementales de reticulados terna.
#
# (1) ∀x(x s x = x)
#
# (2) ∀x(x i x = x)
#
# (3) ∀x∀y(x s y = y s x)
#
# (4) ∀x∀y(x i y = y i x)
#
# (5) ∀x∀y∀z((x s y) s z = x s (y s z))
#
# (6) ∀x∀y∀z((x i y) i z = x i (y i z))
#
# (7) ∀x∀y(x s (x i y) = x)
#
# (8) ∀x∀y(x i (x s y) = x)
#
# 1. Supongamos Dis2 (hipótesis).
# 2. Sea x,y,z un tríplice arbitrario. Queremos probar:
# - xi(ysz)=(xiy)s(xiz).
#
# 3. Primera instanciación de Dis2 Aplicamos Dis2 con la sustitución u:=(zix),v:=y,w:=x. Al sustituir en us(viw)=(usv)i(usw) obtenemos
# - (zix) s (yix) = ((zix) s y) i ((zix) s x) (A)
#
# 4. Usamos la conmutatividad de i y de
# s (axiomas (4) y (3)) para reescribir partes de (A):
# - Por (4): zix=xiz y yix=xiy.
# - Por (3): (zix)sy=ys(zix) y (zix)sx=xs(zix).
#
# Reescribiendo (A) con estas igualdades obtenemos
# - (xiz) s (xiy) = (y s (zix)) i (x s (zix)) (B)
#
# 5. Simplificación del miembro izquierdo de (B). Por conmutatividad de s y i podemos intercambiar el orden en el lado izquierdo:
# - (xiz)s(xiy)=(xiy)s(xiz).
#
# Entonces (B) se reescribe como
# - (xiy) s (xiz) = (y s (zix)) i (x s (zix)) (C)
#
# 6. Aplicación del axioma (7) (absorción) para simplificar. Observa primero que por (4) zix=xiz. Por tanto
# xs(zix)=xs(xiz). Ahora aplicamos (7) con x y y:=z (más exactamente: con  p:=x,q:=z en la forma ps(piq)=p) y obtenemos
# - xs(xiz)=x.
#
# Así, sustituyendo en (C) el factor (xs(zix)) por x, la ecuación (C) queda
#
# - (xiy) s (xiz) = (y s (zix)) i x (D)
#
# 7. Segunda instanciación de Dis2.Ahora aplicamos Dis2 otra vez para el término ys(zix). Usamos la sustitución u:=y,v:=z,w:=x. Entonces Dis2 da
# - y s (zix) = (ysz) i (ysx) (E)
#
# Sustituyendo (E) en (D) para el factor ys(zix) obtenemos
# - (xiy) s (xiz) = ((ysz) i (ysx)) i x (F)
#
# 8. Asociatividad y conmutatividad para reagrupar. Por la asociatividad de i (axioma (6)) podemos agrupar el miembro derecho de (F):
# - ((ysz) i (ysx)) i x = (ysz) i ((ysx) i x) (G)
#
# 9. Por (4) (conmutatividad de i),
# yplicación del axioma (8) (absorción dual xi(xsy)=x). Con p:=x, q:=y. Antes de aplicar (8) queremos tener exactamente la forma xi(xsy). Usamos la conmutatividades: xi(xsy)=x.
#
# Por tanto (ysx)ix=x. Sustituyendo esto en (G) da
# - (xiy) s (xiz) = (ysz)ix (H)
#
# 10. Conmutatividad de i (axioma (4)) aplicada a la derecha de (H) nos permite intercambiar los factores en el i del miembro derecho:
# -(ysz) i x = x i (ysz).
#
# Por tanto (H) se convierte en
# - (xiy) s (xiz) = xi(ysz) (I)
#
# 11. Reescribimos (I) como la igualdad deseada (intercambiando los lados):
# - x i (ysz) = (xiy) s (xiz).
#
# 12. Dado que x,y,z eran arbitrarios, universalizamos las variables y obtenemos Dis1

# %% [markdown]
# ## (14) De una prueba elemental de reticulados acotados de la sentencia elemental pura: Dis1 → ∀x∀u∀v((x s u = 1 ∧ x i u = 0 ∧ x s v = 1 ∧ x i v = 0) → u = v) ##

# %% [markdown]
# 1. Supongamos la hipótesis Dis1
#
# 2. Sea x,u,v un triple arbitrario. Supongamos además las hipótesis sobre ellos:
# - H:xsu=1,xiu=0,xsv=1,xiv=0.
#
# Queremos mostrar u=v.
#
# 3. Primero mostramos que u=ui1.
# - Por el axioma (10) tenemos us1=1 (instanciación de ∀x(xs1=1) con x:=u).
# - Aplicando el axioma (8) pi(psq)=p con p:=u, q:=1 obtenemos ui(us1)=u.
# - Como us1=1, de lo anterior se sigue ui1=u (1)
#
# 4. Sustituimos el 1 por xsv (por H) en (1): u=ui1=ui(xsv) (2) (Aquí usamos 1=xsv de H.)
#
# 5. Aplicamos Dis1 instanciada con a:=u, b:=x, c:=v. Por Dis1 obtenemos
# - ui(xsv)=(uix)s(uiv) (3)
#
# 6. Por H sabemos uix=xiu=0. Sustituyendo en (3) queda ui(xsv)=0s(uiv) (4)
#
# 7. Por el axioma (9) 0st=t (instanciado con t:=uiv) se tiene 0s(uiv)=uiv (5)
#
# 8. De (2),(4),(5) combinadas obtenemos
#
# u=ui(xsv)=(uix)s(uiv)=0s(uiv)=uiv.
#
# Es decir, u=uiv (6)
#
# 9. Ahora obtenemos simétricamente v=uiv:
#
# - Igual que en (3)–(8), intercambiando u y v: por (10) con  x:=v y (8) con p:=v se tiene v=vi1.
#
# - Sustituir 1=xsu (de H) da v=vi(xsu).
#
# - Aplicar Dis1 con a:=v, b:=x, c:=u produce vi(xsu)=(vix)s(viu).
#
# - Por H vix=0, luego v=0s(viu)=viu.
#
# - Usando la conmutatividad de i (axioma (4)) viu=uiv. Por tanto v=uiv (7)
#
# 10. De (6) y (7) se sigue u=uiv=v. Eso es exactamente u=v.
#
# 11. Como x,u,v eran arbitrarios, universalizamos y concluimos ∀x∀u∀v((xsu=1∧xiu=0∧xsv=1∧xiv=0)→u=v).

# %% [markdown]
# ## (15) De una prueba elemental de reticulados complementados de la sentencia elemental pura: Dis1 → ∀x∀u((x s u = 1 ∧ x i u = 0) → u = c(x)) ##

# %% [markdown]
# 1. Supongamos la hipótesis Dis1.
# 2. Sea x y u arbitrarios. Supongamos las hipótesis H:xsu=1 y xiu=0.
#
# - Queremos probar u=c(x).
#
# 3. Mostramos primero u=ui1.
# - Instanciamos (A10) con t:=u: obtenemos us1=1.
# - Aplicamos el axioma (8) pi(psq)=p con p:=u, q:=1, por lo que ui(us1)=u.
# - Como us1=1, concluimos u=ui1 (1)
#
# 4. Reemplazamos 1 por xsc(x).
# - Por (A11) sabemos xsc(x)=1. Sustituyendo en (1) obtenemos u=ui(xsc(x)) (2)
#
# 5. Aplicamos Dis1 instanciada con  a:=u, b:=x, c:=c(x). Es decir, usamos ui(xsc(x))=(uix)s(uic(x)) (3)
#
# 6. De la hipótesis H tenemos uix = xiu = 0. Sustituyendo en (3) se obtiene u i (xsc(x)) = 0 s (uic(x)) (4)
#
# 7. Por (A9) 0st=t, con t:=uic(x), deducimos
# - 0 s (uic(x)) = uic(x) (5)
#
# 8. Combinando (2),(4),(5) llegamos a
#
# - u = ui(xsc(x)) = (uix)s(uic(x)) = 0s(uic(x)) = uic(x).
#
# - Es decir u=uic(x) (6)
#
# 9. Mostramos ahora c(x)=uic(x) (simétrico al paso anterior):
# - Por (A11) con t:=x conocemos xsc(x)=1, pero también por hipótesis xsu=1. Usaremos la segunda forma para reemplazar 1.
#
# - Como en (3), aplicamos Dis1 pero ahora con a:=c(x), b:=x, c:=u. Obtenemos c(x)i(xsu) = (c(x)ix)s(c(x)iu).
#
# - Usando xsu=1 (hipótesis) la igualdad anterior es c(x)i1 = (c(x)ix)s(c(x)iu) (7)
#
# - Por (A12) c(x)ix=0. Entonces (7) queda c(x)i1 = 0s(c(x)iu).
#
# - Por (A9) 0s(c(x)iu)=c(x)iu. Así c(x)i1 = c(x)iu.
#
# - Igual que en el paso 3, usando (A10) y (8) con p:=c(x) deducimos c(x)=c(x)i1. Entonces c(x)=c(x)i1=c(x)iu.
#
# - Por conmutatividad de i ((4) del reticulado) c(x)iu=uic(x). Por tanto c(x) = uic(x) (8)
#
# 10. De (6) y (8) obtenemos u=uic(x)=c(x).
#
# 11. Como x,u eran arbitrarios, universalizando sobre x,u llegamos a
# - ∀x∀u((xsu=1∧xiu=0)→u=c(x)).

# %% [markdown]
# ## (16) De una prueba elemental de reticulados complementados de la sentencia elemental pura: Dis1 → ∀x∀y(c(x i y) = c(x) s c(y))   ##

# %% [markdown]
# Puede usar como teorema la sentencia: Dis1 → ∀x∀u∀v((x s u = 1 ∧ x i u = 0 ∧ x s v = 1 ∧ x i v = 0) → u = v)
#
# Como podemos usar el teorema y ya sabemos que vale que (xiy) i c(xiy)=0 y (xiy) s c(xiy)=1 entonces si probamos que (xiy) i (c(x) s c(y))=0 y (xiy) s (c(x) s c(y))=1 entonces vamos a poder concuir que c(xiy)=c(x)sc(y)
#
# Notar que es obvio probar que c(xiy) es complemento de xiy
#
# Sea u=c(x)sc(y). Queremos probar que u=c(xiy).
#
# Para aplicar el teorema auxiliar necesitamos comprobar:
# (xiy)su=1 y (xiy)iu=0
#
# **INFIMO**
# Tenemos que (xiy) i (c(x) s c(y)) = ((xiy) i c(x)) s ((xiy) i c(y)) esto por Dis1, aca hacemos manejo con axiomas para llegar a
# - (yi(x i c(x))) s (xi(y i c(y)))
#
# Ahora por ax de complementos (yi0) s (xi0) = 0 s 0 = 0
#
# **Supremo**
# Idea dual usando el teorema de que Dis1 -> Dis 2 (esto hay que ver si demostrarlo)

# %% [markdown]
# ## (17) De una prueba elemental de grafos bicoloreados de la sentencia elemental pura: ∀x (∀z(¬(z = x) → r(x, z)) → ∀u∀v((¬(u = x) ∧ ¬(v = x)) → ¬r(u, v))) ##

# %% [markdown]
# Note que la sentencia anterior tambien es una sentencia elemental de grafos.
# Puede haber una prueba elemental de grafos de esta sentencia?
#
# Axiomas elementales de grafos bicoloreados.
#
# (1) ∀x¬r(x, x)
#
# (2) ∀x∀y(r(x, y) → r(y, x))
#
# (3) ∀x∀y(r(x, y) → ((R(x) ∧ ¬R(y)) ∨ (¬R(x) ∧ R(y))))
#
# **Prueba.**
#
# Sean a,u,v∈G fijos pero arbitrarios. Supongamos ∀z(¬(z=a)→r(a,z)) y además supongamos ¬(u=a) y ¬(v=a).
#
# Por la suposición ∀z(¬(z=a)→r(a,z)) y como ¬(u=a) y ¬(v=a), obtenemos r(a,u)yr(a,v).
#
# Aplicando el axioma (3) al par (a,u) obtenemos
#
# r(a,u)→((R(a)∧¬R(u)) ∨ (¬R(a)∧R(u))),
#
# y por tanto se da
#
# (R(a)∧¬R(u))∨(¬R(a)∧R(u)) (1)
#
# Análogamente, aplicando el axioma (3) al par (a,v) obtenemos (R(a)∧¬R(v))∨(¬R(a)∧R(v)) (2)
#
# Supongamos, para probar por abs, que r(u,v) se da. Entonces por ax (3) aplicado a (u,v) tenemos
# - r(u,v)→((R(u)∧¬R(v))∨(¬R(u)∧R(v))),
# y por tanto (porque suponemos r(u,v)) se da
# - (R(u)∧¬R(v))∨(¬R(u)∧R(v)).
# (3)
#
# Ahora haremos un análisis de casos según el valor de R(a):
#
# **Caso 1:** R(a) es verdadero. De (1) y (2) con R(a) obtenemos ¬R(u) y ¬R(v). Entonces R(u) es falso y R(v) es falso, es decir R(u)=R(v). Pero (3) exige que R(u) y R(v) sean distintos. Contradicción.
#
# **Caso 2:** ¬R(a) es verdadero.
# De (1) y (2) con ¬R(a) obtenemos R(u) y R(v). Entonces R(u)=R(v)= verdadero, de nuevo R(u)=R(v). Pero (3) exige que sean distintos. Contradicción.
#
# En ambos casos obtenemos contradicción con (3). Por lo tanto la suposición r(u,v) es imposible y concluimos ¬r(u,v).
#
# Queda generalizar

# %% [markdown]
# ##(20) Sea τ = (∅, {s, i}, ∅, {(s, 2),(i, 2)})  ##
#
# (a) ¿Cuantas estructuras de tipo τ con universo igual a {1, 2, 3, 4, 5, 6, 7, 8, 9} hay? (Puede usar el Lema 1)
#
# (b) ¿Alguna de ellas es un reticulado terna?
#
# (c) Cuales de ellas son ”esencialmente” reticulados terna
#
# (d) De una biyeccion entre el conjunto formado por todos los reticulados terna y un subconjunto del conjunto de todas las estructuras de tipo τ

# %% [markdown]
# Lema 1. Se tiene que:
# (1) Dados A, B conjuntos finitos no vacíos, hay |B|^|A| funciones tales que su dominio es A y
# su imagen está contenida en B
# (2) si A es un conjunto cualquiera, entonces hay 2^|A| subconjuntos de A.
# a) El tipo tiene dos palabras en el conjunto F (s e i). La aridad de las mismas es 2, por lo
# que podemos interpretar que i(s),i(i):AxA→A (o sea que la interpretación de s e i tiene
# dominio AxA e imagen A)
# Por el Lema 1, el número de funciones A^2→A es |A|^|A|^2. Aquí |A| = 9 y |A|^2 = 81 luego
# hay 9^81 estructuras de tipo τ
# b) No, pues un reticulado terna es una tres-upla (A,s,i) con universo y dos operaciones
# binarias en, mientras que una estructura del tipo τ es una tupla (A,i) con un universo y una
# cierta función i con dominio CuFuR (unión de los conjuntos de la estructura) que cumple
# ciertas propiedades .
# c) Aquellas estructuras de tipos τ que se pueden entender (o simular) reticulados terna
# (A,i(s),i(i)) es un reticulado terna (es decir que las interpretaciones de s e i cumplen las 7
# identidades y A es un conjunto no vacío).
# d)
# Sea P el conjunto de todos los reticulados terna.
# Sea S el conjunto de todas las estructuras de tipo τ que sean del tipo de Ret. terna = (∅, {s,
# i}, ∅, {(s, 2),(i, 2)})
# Φ:P⟶S,
# (A, s, i) → (A,{(s, i(s)), (i, i(i))})
# (Como habíamos dicho sería que la función i interprete a los símbolos s e i como las
# operaciones binarias ya conocidas)

# %% [markdown]
# ## (21) Sea τ = (∅, ∅, {rel}, {(rel, 2)}. Sea A = (A, i), con A = {1, 3, 5, 6, 30} y i(rel) = {(i, j) ∈ A^2: i divide a j}  ##
#
# (a) De una formula elemental pura φ la cual tenga como su unica variable
# libre a x y la cual sea verdadera en A cuando asignamos a x el valor
# i ∈ A si y solo si i = 1
#
# (b) De una formula elemental pura φ la cual tenga como su unica variable
# libre a x y la cual sea verdadera en A cuando asignamos a x el valor
# i ∈ A si y solo si i = 3
#
# (c) De una formula elemental pura φ la cual tenga como su unica variable
# libre a x y la cual sea verdadera en A cuando asignamos a x el valor
# i ∈ A si y solo si i = 5
#
# (d) De una formula elemental pura φ la cual tenga como su unica variable
# libre a x y la cual sea verdadera en A cuando asignamos a x el valor
# i ∈ A si y solo si i = 6
#
# (e) De una formula elemental pura φ la cual tenga como su unica variable
# libre a x y la cual sea verdadera en A cuando asignamos a x el valor
# i ∈ A si y solo si i = 30

# %% [markdown]
# (a) Fórmula que caracteriza a 1
#
# φ1 (x):∀y rel(x,y).
#
# Justificación: sólo x=1 lo cumple pues es el único que divide a todos los elementos (el
# mínimo).
#
# (b) Fórmula que caracteriza a 3
#
# 𝜑3(x): ∃a ∃b ∃c (¬(a=b) ∧ ¬(a=c) ∧ ¬(b=c) ∧ rel(a,x) ∧ φ1(a) ∧ rel(x,b) ∧ rel(x,c))
#
# Justificación: sólo x=3 funciona pues tiene exactamente esos dos múltiplos dentro de A y es
# solo dividido por 1.
#
# (c) Fórmula que caracteriza a 5
# φ5(x): ∃a ∃b (¬(a=b) ∧ rel(a,x) ∧ φ1(a)) ∧ rel(x,b)
#
# Justificación: sólo x=5 funciona pues tiene exactamente ese múltiplo dentro de A y es solo
# dividido por 1.
#
# (d) Fórmula que caracteriza a 6
#
# φ6(x): ∃a ∃b ∃c (¬(a=b) ∧ ¬(a=c) ∧ ¬(a=c) ∧ rel(a,x) ∧ rel(b,x) ∧ rel(x,c) ∧ φ1(a) ∧
# φ3(b))
#
# Justificación: sólo x=6 funciona pues tiene exactamente un múltiplo dentro de A y es dividido
# por 1 y 3.
#
# (e) Fórmula que caracteriza a 30
#
# φ30(x):∀y rel(y,x)
#
# Justificación: sólo x=30 es el único elemento dentro de A que es dividido por todos (el
# máximo).
#
# a) El tipo tiene dos palabras en el conjunto F (s e i). La aridad de las mismas es 2, por lo
# que podemos interpretar que i(s),i(i):AxA→A (o sea que la interpretación de s e i tiene
# dominio AxA e imagen A)
# Por el Lema 1, el número de funciones A^2→A es |A|^|A|^2. Aquí |A| = 9 y |A|^2 = 81 luego
# hay 9^81 estructuras de tipo τ
#
# b) No, pues un reticulado terna es una tres-upla (A,s,i) con universo y dos operaciones
# binarias en, mientras que una estructura del tipo τ es una tupla (A,i) con un universo y una
# cierta función i con dominio CuFuR (unión de los conjuntos de la estructura) que cumple
# ciertas propiedades .
#
# c) Aquellas estructuras de tipos τ que se pueden entender (o simular) reticulados terna
# (A,i(s),i(i)) es un reticulado terna (es decir que las interpretaciones de s e i cumplen las 7
# identidades y A es un conjunto no vacío).
#
# d)
# Sea P el conjunto de todos los reticulados terna.
# Sea S el conjunto de todas las estructuras de tipo τ que sean del tipo de Ret. terna = (∅, {s,
# i}, ∅, {(s, 2),(i, 2)})
# Φ:P⟶S,
# (A, s, i) → (A,{(s, i(s)), (i, i(i))})
# (Como habíamos dicho sería que la función i interprete a los símbolos s e i como las
# operaciones binarias ya conocidas)

# %% [markdown]
# ##(24) Sea τ = ({ce, un}, {Fu}, {V}, {(Fu, 2),(V, 1)} y sea Σ formado por las siguientes sentencias elementales puras de tipo τ :   ##
#
# ∀x∀y (V(x) → (Fu(x, y) = ce))
#
# ∀x∀y (¬V(y) → (Fu(x, y) = un))
#
# ∀x∀y (Fu(x, y) = Fu(y, x))
#
# De una prueba elemental de ∀x∀y ((Fu(x, y) = ce) ∨ (Fu(x, y) = un)) en
# (Σ, τ ).

# %% [markdown]
# 1. Sean a,b∈A elementos arbitrarios.
# 2. Usando y:=a, x:=b en (2) nos da ¬V(b) → Fu(b,a)=un.
# 3. Usando x:=a, y:=b en (1) V(a) → Fu(a,b)=ce.
# 4. Usando x:=a, y:=b en (3) nos da Fu(a,b)=Fu(b,a).
# 5. Supongamos V(a). De paso 2 obtenemos Fu(a,b)=ce.
# 6. Supongamos ¬V(a) obtenemos que Fu(b,a)=un. Usando el paso 3 tenemos que Fu(b,a)=Fu(a,b)=un.
#
# Como no puede ocurrir simultaneamente V(a) y ¬V(a), entonces podemos concluir que Fu(a,b)=ce ∨ Fu(a,b)=un.
#
# Como a,b fueron elementos arbitrarios, generalizamos
