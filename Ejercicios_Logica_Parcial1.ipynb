# %% [markdown]
# <a href="https://colab.research.google.com/github/CamilaNanini/LogicaFamaf2025/blob/main/Ejercicios_Logica_Parcial1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Inyectiva:
# Cada elemento del conjunto de salida (codominio) es la imagen de a lo sumo un elemento del conjunto de entrada (dominio).
#
# Sobreyectiva:
# Cada elemento del conjunto de salida (codominio) es la imagen de al menos un elemento del conjunto de entrada (dominio).

# %% [markdown]
# # LEMAS

# %% [markdown]
# **Lema 1.a**:Sean (P, ≤) y (P′, ≤′) posets. Supongamos F es un isomorfismo de (P, ≤) en (P′, ≤′).Para x, y ∈ P, tenemos que x < y si y solo si F(x) <′ F(y).
#
# -->
#
# Tomamos un x,y en P tal que x<y entonces por definición de < tenemos que x≤y & x/=y. Como F preserva el orden al ser un homomorfismo entonces F(x)≤′F(y) pero F es inyectiva entonces F(x)/=F(y). Por lo que F(x)≤′F(y) y F(x)/=F(y) lo que esto da la definición F(x)<F(y).
#
# <--
#
# ... Usamos una idea similar pero con F^{-1}

# %% [markdown]
# **Lema 1.c**:Sean (P, ≤) y (P′, ≤′) posets. Supongamos F es un isomorfismo de (P, ≤) en (P′, ≤′).Para cada x ∈ P, se tiene que x es maximal (resp. minimal) en (P, ≤) si y solo si F(x) es maximal (resp. minimal) en (P′, ≤′).
#
# -->
#
# Sea m en P tal que m es maximal. Veamos por absurdo que si debe de ser maximal en P′. Supongo que existe un z∈P′ tal que F(m)<′z. Como F es sobre entonces existe un d∈P tal que F(d)=z o sea, F(m)<′F(d). Por Lema 1.a sabemos que entonces m<d.Esto es absurdo pues m maximal
#
# <--
#
# Sea m en P tal que F(m) es maximal de (P′, ≤′). Vamos a probarlo por el absurdo. Supongo que existe un b∈P tal que m<b. Directamente por Lema 1.a tengo que F(m)<′F(b), lo cual es absurdo porque F(m) es maximal.

# %% [markdown]
# Lema 1.f: Lema 1. Sean (P, ≤) y (P′, ≤′) posets. Supongamos F es un isomorfismo de (P, ≤) en (P′, ≤′).Para x, y ∈ P, tenemos que x ≺ y si y solo si F(x) ≺′ F(y).
#
# ⇒
#
# Supongamos x≺y. Entonces x<y, por lo que F(x)<′F(y) (por la propiedad del isomorfismo). Supongamos, buscando contradicción, que existe w′∈P′ con F(x)<′w′<′F(y). Como F es biyectiva existe w∈P con F(w)=w′. Aplicando la equivalencia del iso obtenemos x<w<y, contradicción con que x≺y. Por tanto no existe tal w′ y se cumple F(x)≺′F(y).
#
#
# ⇐ Igual aplicando F^{-1} (que también es isomorfismo) llegamos a la implicación opuesta.

# %% [markdown]
# Lema 2. Dado un reticulado par (L, ≤), se cumplen las siguientes.
#
# (1) x ≤ x s y, cualesquiera sean x, y ∈ L
#
# (2) x i y ≤ x, cualesquiera sean x, y ∈ L
#
# (3) x s x = x, cualesquiera sea x ∈ L
#
# (4) x i x = x, cualesquiera sea x ∈ L
#
# (5) x s y = y s x, cualesquiera sean x, y ∈ L
#
# (6) x i y = y i x, cualesquiera sean x, y ∈ L
#
# Prueba perfecta de (1). Sean a, b ∈ L, fijos. Por definicion de s tenemos que
# a s b = sup({a, b}). O sea que por definicion de supremo de un conjunto tenemos que a s b es cota superior del conjunto {a, b} en (L ≤). O sea que a ≤ a s b. Ya que a, b eran arbitrarios, hemos probado que vale (1).
#
# Prueba de (2) Sea a,b en L fijos y arbitrarios. Por definicion a i b = inf {a,b}. O sea que por definicion de ínfimo de un conjunto tenemos que a i b es cota inferior el conjunto {a,b} en (L,<=) . Por lo que a i b <= a. Como a,b eran arbitrarios vale para todos los a,b en L
#
# Prueba perfecta de (3). Sea a ∈ L, fijo. Por definicion de s tenemos que a s
# a = sup({a, a}) = sup({a}). O sea que debemos probar que a = sup({a}). Es claro
# que a es cota superior de {a}. Ademas es claro que si z es cota superior de {a},
# entonces z ≥ a. O sea que por definicion de supremo de un conjunto tenemos que
# a = sup({a}). O sea que hemos probado que a s a = a. Ya que a era arbitrario,
# hemos probado que vale (3).
#
# Prueba de (4).Sea a en L fijo y arbitrario. Por definicion de infimo a i a = inf {a,a} = inf {a}. O sea que hay que ver que a = inf {a}. Es claro que a es cota inferior de {a}, además es claro que dado un z cota inferior de {a} se da que z<=a. Entonces por definicion de infimo de un conjunto se da que a = inf {a}
#
# Prueba de (5). Sea a,b en L fijos y arbitrarios. Por definicion a s b = sup {a,b} y b s a = sup {b,a} pero {b,a} = {a,b} por propiedad de los conjuntos, por lo que sup {a,b} = sup {b,a} (es decir los supremos coinciden), entonces podemos concluir que a s b = b s a

# %% [markdown]
# Lema 3. Dado un reticulado par (L, ≤), se tiene que:
# (1) x s (x i y) = x, cualesquiera sean x, y ∈ L
# (2) x i (x s y) = x, cualesquiera sean x, y ∈ L
#
# Proof. (1). Sean a, b ∈ L, fijos. Por definicion de s debemos probar que sup({a, a i b}) = a. O sea debemos probar que a es la menor cota superior de {a, a i b}. Por un lema anterior tenemos que a i b ≤ a y obviamente se da a ≤ a, lo cual nos dice que a es cota superior de {a, a i b}. Es claro que es menor o igual que cualquier otra cota superior. O sea que hemos probado que a s (a i b) = a, lo cual ya que a, b eran elementos arbitrarios nos dice que vale (1).

# %% [markdown]
# #**(1) Sea R una relacion de equivalencia sobre A y sean a, b ∈ A. Entonces son equivalentes**
# (a) aRb . (b) a/R = b/R . (c) a/R ∩ b/R ̸= ∅

# %% [markdown]
# Usaremos para la demostración que R es una relación de equivalencia, o sea que es reflexiva, simétrica y transitiva
#
# *   Reflexividad xRx, cualesquiera sea x ∈ A
# *   Transitividad xRy y yRz implica xRz, cualesquiera sean x, y, z ∈ A
# *   Simetria xRy implica yRx, cualesquiera sean x, y ∈ A
#
# **a => b**
#
# Suponemos aRb  y debemos probar a/R = b/R (lo hacemos viendo ambas contenciones)
#
# a/R ⊆ b/R : Tomamos un y ∈ a/R, entonces aRy. Por simetría sacamos que
# yRa; usamos la suposición inicial (aRb) y la propiedad transitiva y obtenemos yRb. Por simetría nuevamente llegamos a que bRy. Luego y ∈ b/R. Así demostramos a/R ⊆ b/R.
#
# b/R ⊆ a/R : Lo mismo al vesre.
#
# **b => c**
#
# Suponemos a/R = b/R y debemos probar a/R ∩ b/R ̸= ∅
#
# Es trivial ver esto ya que estamos suponiendo que son iguales, de todas maneras podemos hacer una demostración más formal. Si tomamos un x ∈ A fijo tal que aRx , por suposición inicial entonces bRx. De bRx podemos ver que xRb por simetría y uniendo esto con aRx obtenemos por transitividad que aRb. Como x era un elemento cualquiera que estuviera en ambas clases de equivalencias podemos generalizar a que esto ocurre con todos los elementos que se encuentren en esa situación. Por lo que llegamos a ver que la intersección no es vacía.
#
# **c => a**
# Como suponemos que a/R∩b/R=∅, entonces existe x∈A tal que aRx y bRx.
# De aRx por simetría obtenemos xRa; con bRx y transitividad: bRa.

# %% [markdown]
# #**(2) Sea A un conjunto cualquiera.**
# (a) Defina “particion de A”
#
# (b) Sea P una particion de A. Definir RP y probar que es una relacion de
# equivalencia sobre A
#
# (c) Sea R una relacion de equivalencia sobre A. Definir A/R y probar que
# es una particion de A

# %% [markdown]
# a) Dado un conjunto A por una particion de A entenderemos un conjunto P tal que:
# - Cada elemento de P es un subconjunto no vacio de A
# - Si S1, S2 ∈ P y S1 ̸= S2, entonces S1 ∩ S2 = ∅ (disjuntos de a pares)
# - A = {a : a ∈ S, para algun S ∈ P} (la unión de todos los elementos de P deben ser A)
#
# b) Definimos
# R_p ={(a,b)∈A×A:∃S∈P tal que a∈S y b∈S}.
# (“a está relacionada con b” si ambos pertenecen a la misma parte de la partición.)
# Hay que ver entonces que es reflexiva, simétrica y transitiva.
#
# *   Reflexividad xRx, cualesquiera sea x ∈ A
# *   Transitividad xRy y yRz implica xRz, cualesquiera sean x, y, z ∈ A
# *   Simetria xRy implica yRx, cualesquiera sean x, y ∈ A
#
# Reflexiva: Sea a∈A fijo y arbitrario. Por la propiedad 3 de las particione, existe S∈P con a∈S. Entonces (a,a) ∈R_P (pues sería verificar que ese elemento está dos veces en S. trivialmente cierto). Luego aR_P a para todo a (pues dijimos que es arbitrario).
#
# Simétrica. Supongamos (a,b)∈R_P. Entonces existe S∈P con a∈S y b∈S. Eso implica b∈S y a∈S, por lo que (b,a)∈R_P. Así aR_Pb⇒bR_Pa.
#
# Transitiva. Supongamos (a,b)∈R_P y (b,c)∈R_P. Entonces existen S1,S2∈P tales que a,b∈S1 y b,c∈S2. Como b∈S1 y b∈S2
# entonces b∈S1∩S2 y las partes de la partición son disjuntas salvo que sean iguales (propiedad dos de la definición de particiones), entonces si o si S1=S2. Por lo que tendríamos ahora que a,c ∈ S1 o sea (a,c) ∈ R_P. Por lo que podemos escribir que si aR_Pb y bR_Pc =>
# aR_Pc.
#
# c) Dada una relacion de equivalencia R sobre A y a ∈ A, definimos:
# a/R = {b ∈ A : aRb} (clase de equivalencia) y A/R al conjunto {a/R : a ∈ A} (cociente de A por R).
# Debemos ver que A/R es una partición => ver las 3 prop de una partición...
# 1) Cada a/R es no vacio, esto porque para todo a∈A tenemos que se cumple la reflexibilidad por lo que aRa y por lo tanto hay por lo menos un elemento en a/R.
#
# 2) Dos clases de equivalencia que son distintas son disjuntas. Tomemos a,b∈A fijos y arbitrarios. Si suponemos que a/R /= b/R y a/R∩b/R /= ∅, entonces va a existir un cierto x tal pertenezca a la intersección de las dos clases de equivalencias por lo que se relaciona con a y b, o sea x∈a/R y x∈b/R => aRx y bRx. Usando simetría y transitividad se obtiene aRb; por lo que se llega a un absurdo. Así, si a/R y b/R no son iguales entonces su intersección es vacía.
#
# 3) La unión de clases da A, sea a un elemento cualquiera de A (a∈A). Entonces a∈a/R, por lo que a pertenece a alguna clase de A/R. Esto prueba que la unión de los elementos de A/R da A

# %% [markdown]
# #**(3) Sea F : A → B.**
#
# (a) Pruebe entonces que la ecuacion
# f(a/ ker(F)) = F(a)
# define en forma inambigua una funcion f de A/ ker(F) en B.
#
# (b) Pruebe que f es inyectiva.
#
# (c) Pruebe que si F es sobreyectiva, entonces f es una biyeccion.
#
# Recordemos que dada una funcion F : A → B, se define ker(F) = {(a, b) ∈ A2: F(a) = F(b)}.

# %% [markdown]
# a) Hay que comprobar que está bien definida (es decir, no depende del representante elegido).
#
# Primero pensemos que quiere decir a/ker(F) = {x∈A:(a,x)∈ker(F)}={x∈A:F(x)=F(a)}, es decir el conjunto de todos los elementos de A que F manda al mismo valor que a.
#
# Tomemos a,b ∈ A con a/ker(F)=b/ker(F). Por definición de clases,a/ker(F)=b/ker(F) ⇔ (a,b)∈ker(F) ⇔ F(a)=F(b). Entonces
# f(a/ker(F)) = F(a)=F(b) = f(b/ker(F)).
#
# Esto muestra que si dos representantes son de la misma clase, la imagen  es la misma; por tanto f está bien definida y es una función tal que f:A/ker(F)→B.
#
# b) f es inyectiva.
# Sea a/ker(F),b/ker(F)∈A/ker(F) y supongamos f(a/ker(F))=f(b/ker(F)). Por definición f(a/ker(F))=F(a) y f(b/ker(F))=F(b), así que F(a)=F(b). Entonces
# (a,b)∈ker(F), lo que implica a/ker(F)=b/ker(F). Por tanto siempre que f(a/ker(F))=f(b/ker(F)) se tiene a/ker(F)=b/ker(F); esto es, por definición inyectividad.
#
# c) Ya sabemos por el punto anterior que f es inyectiva. Queda probar que es sobreyectiva, y por tanto biyectiva.
#
# Supongamos F sobreyectiva. Sea y∈B. Como F es sobreyectiva existe a∈A tal que F(a)=y. Entonces por definición
# f(a/ker(F))=F(a)=y. Así para todo y∈B existe una clase b/ker(F) con f(b/ker(F))=y, es decir f es sobreyectiva.

# %% [markdown]
# #**(4) Sea F : (P, ≤) → (P′, ≤′) un homomorfismo de posets. Supongamos que F es suryectiva. Entonces**
#
# (a) Si (P, ≤) es un conjunto totalmente ordenado, (P′, ≤′) tambien lo es
#
# (b) Si (P, ≤) tiene un elemento maximo, (P′, ≤′) tiene un elemento maximo

# %% [markdown]
# a) Como (P,≤) es totalmente ordenado, para todo x,y∈P, se cumple: x≤y o bien y≤x.
# Tomemos ahora a′,b′∈P′. Como F es sobreyectiva, existen a,b∈P tales que:F(a)=a′,F(b)=b′
# Como en P el orden es total, ocurre que a≤b o b≤a.
# Si a≤b --> F(a)≤′F(b), o sea a′≤′b′.
# Si b≤a --> F(b)≤′F(a), o sea b′≤′a′.
#
# En cualquier caso, se cumple que en P′, para cualquier par a′,b′, tenemos a′≤′b′.
#
# b) Un elemento máximo en un poset (P,≤) es un m∈P tal que: ∀x∈P: x≤m.
# Supongamos que m∈P es un elemento máximo. Tomemos un elemento cualquiera y′∈P′ (fijo). Como F es sobreyectiva, existe y∈P con F(y)=y′.
# Como m es máximo entonces está por encima de todos los elementos de P,en particular y≤m.
#
# Como F es homomorfismo de posets y con y≤m se obtiene que: F(y)≤′F(m).
# Pero F(y)=y′, entonces tenemos:
#  y′≤′F(m):∀y′∈P′ (ya que y′ era un elemento cualquiera). Eso significa que F(m) es un elemento máximo de P′.

# %% [markdown]
# #**(5) Dado un poset (P, ≤) y a, b ∈ P diremos que b es base de a cuando se de que b < a y c ≤ b, para cada c ∈ P tal que c < a. Pruebe que si F : (P, ≤) → (P′, ≤′) un isomorfismo de posets, entonces cualesquiera sean x, y ∈ P, tenemos que x es base de y si y solo si F(x) es base de F(y).**

# %% [markdown]
# Lema 1. Sean (P, ≤) y (P′, ≤′) posets. Supongamos F es un isomorfismo de (P, ≤) en (P′, ≤′).
# (a) Para x, y ∈ P, tenemos que x < y si y solo si F(x) <′ F(y).
# ... (sigue pero solo nos interesa esto)
#
# b es base de a en (P,≤) cuando: b<a, y
#  para todo c ∈ P tal que c<a se cumple c≤b.
#
# Sea F:(P,≤)->(P',≤') un isomorfismo de posets
#
# Probaremos: para cualesquiera x,y ∈ P
# x es base de y <-> F(x) es base de F(y).
#
# **-->**
#
# Por la condición (i) de ser base, tenemos que se da que x<y. Aplicando el Lema 1(a) obtenemos F(x)<'F(y). Así se cumple la condición (i) para F(x) respecto de F(y).
#
# Sea ahora d' ∈ P' tal que d'<'F(y). Como F es sobreyectiva existe d ∈ P con F(d)=d'. Por Lema 1(a) (en la dirección contraria) de d'<'F(y) se da que d<y.
#
# Dado que x es base de y y además d<y se obtiene d≤x. Aplicando que F es biyectiva y preserva ≤ (propiedad del isomorfismo) se tiene F(d)≤'F(x), es decir d'≤'F(x).
# Como d' era arbitrario con d'<'F(y), hemos probado que para todo d' con d'<'F(y) se cumple d'≤'F(x)$. Esa es la condición (ii) para que F(x) sea base de F(y)
#
# **<--**
#
# La demostración inversa se obtiene aplicando exactamente el mismo argumento a F^{-1} (que también es un isomorfismo entre (P',≤') y (P,≤)):
#
# De F(x)<'F(y) se deduce por Lema 1(a) que x<y. (Condición (i).)
# Sea c∈P con c<y. Entonces F(c)<'F(y). Como F(x) es base de F(y), de F(c)<'F(y) se sigue F(c)≤'F(x). Aplicando F^{-1} y la correspondencia de ≤, obtenemos c≤x
# Eso prueba la condición (ii) para x respecto de y.
# Por tanto x es base de y.

# %% [markdown]
# #**(6) Sean (P, ≤) y (P′, ≤′) posets.  Supongamos F es un isomorfismo de (P, ≤) en (P′, ≤′). Supongamos a, b ∈ P son tales que {x ∈ P : a < x < b} tiene exactamente 4 elementos. Pruebe que entonces {z ∈ P′: F(a) <′z <′F(b)} tiene exactamente 4 elementos.**

# %% [markdown]
# Probar que F:(P,≤)→(P′,≤′) es un isomorfismo de posets. Sean a,b∈P y
# S:={x∈P:a<x<b} con |∣S|=4 --> S′:={z∈P′:F(a)<′z<′F(b)} y |S`|=4
# Hipótesis: S:={x∈P:a<x<b} con ∣S∣=4
#
# Por el ítem (a) del Lema 1 (que F mantiene el orden de <), ocurre que al tomar a<x y x<b y aplicarles F se obtienen F(a)<′F(x) y F(x)<′F(b); es decir cualquier x que esté en S va a llegar por medio de F a S′. Y como estamos en un isomorfismo lo mismo ocurrirá para los elementos de S' hacia los elementos de S, pues F-{1} es una función biyectiva qué también es homorfa. O sea que dado un x',d',y' en S' tal que x' <' d' <y' como F es biyectiva (en particular sobre) entonces existen a,b,c en P tal que F{-1}(x')=a ... entonces como F{-1} es un homomorfismo se tiene que a<b<c. Por lo que todo elemento de S' esta en S.
# Supongamos que esto no es verdad y planteamos los casos en que:
#
# 1. Un elemento de S no está en S′: Sea e1 un elemento que está en S --> para ello debe de cumplir necesariamente que a<e1 y e1<b pero entonces al aplicarle la función F se llegaría a un absurdo ya que la misma mantiene el orden al ser un isomorfismo. Por lo que esto no puede ocurrir.
#
# 2. Un elemento de S′ no está en S: Sea e2 un elemento que está en S′ --> entonces debe de cumplir que F(a)<′e2 y e2<′F(b), usemos la función F{-1} (la cual es biyectiva y preserva el homomorfismo) para poder llevar estos elementos a S; como F{-1} es bi entonces existe un e3 en S talque F(e3)=e2. Ahora obtenemos que F{-1}(F(a))<F{-1}(e2) y F{-1}(e2)<F{-1}(F(b)) --> a<e2 y e2<b pero estas son las condiciones que se requerían para estar en S y entonces estamos ante un absurdo. Por lo que esto no puede ocurrir
#
# Entonces sabemos que TODOS los elementos que están en S si o si van a estar en S′, en particular como S tiene solo 4 elementos (a1,...,a4) entonces S′ va a tener que tener 4 elementos "los x en S tal que se les aplicó la F" (F(a1),...,F(a4))

# %% [markdown]
# #**(7) Pruebe que si F : (P, ≤) → (P′ , ≤′) un isomorfismo de posets,entonces son equivalentes:**
# (a) (P, ≤) tiene exactamente tres elementos minimales
# (b) (P′, ≤′) tiene exactamente tres elementos minimales

# %% [markdown]
# a⇒b
#
# Sean a,b,c∈P los 3 minimales, como F se trata de un isomorfismo de (P,≤) en (P′,≤′) usando el lema 1.c (se mantiene el minimal) tengo que F(a),F(b),F(c) son minimales en (P′,≤′).
# Resta ver que no existan más, esto lo vamos a lograr viendo por el absurdo. Si suponemos que existe un d′∈P′ tal que es minimall, como F es biyectiva y en particular sobre entonces existe un e∈P tal que F(e)=d′ nuevamente por el lema 1.c tengo que e es minimam en (P,≤) pero esto es un absurdo pues ya dijimos que a,b,c eran los minimales. Entonces cocluimos que solo hay tres minimales en P′
#
# b⇒a
#
# Paso similar al anterior pero al vesre

# %% [markdown]
# #**(8) Pruebe que si F : (P, ≤) → (P′, ≤′) un isomorfismo de posets, entonces son equivalentes:**
# (a) (P, ≤) es denso
# (b) (P′, ≤′) es denso

# %% [markdown]
# Prueba de a<-->b
#
# Sea F:(P,≤)→(P′,≤′) un isomorfismo de posets (biyectiva y que preserva y refleja el orden).
# Queremos probar:
# (P,≤) es denso⟺(P′,≤′) es denso.
#
# ⇒ Supongamos (P,≤) denso.
#
# Tomemos cualesquiera a′,b′∈P′ con a′<′b′. Como F es sobreyectiva, existen a,b∈P tales que F(a)=a′ y F(b)=b′.
# Por el Lema 1(a) a<b . Por densidad de P existe c∈P tal que a<c<b. Aplicando de nuevo el Lema 1(a) a c obtenemos a′=F(a)<′F(c)<′F(b)=b′.
#
# Así F(c)∈P′ está estrictamente entre a′y b′. Como a′,b′ eran arbitrarios, (P′,≤′) es denso.
#
#
# ⇐ Supongamos (P′,≤′) denso.
#
# Tomemos a,b∈P con a<b. Aplicando el Lema 1(a) tenemos F(a)<′F(b). Como suponemos que P′ es denso existe z′∈P′ tal que F(a)<′z′<′F(b).
# Como F es sobreyectiva, existe c∈P con F(c)=z′. Aplicando Lema 1(a) hacia atrás obtenemos a<c<b. Como a,b eran arbitrarios, (P,≤) es denso.

# %% [markdown]
# #**(9) Pruebe que si F : (P, ≤) → (P′, ≤′) un isomorfismo de posets, entonces cualesquiera sea x ∈ P, tenemos que son equivalentes:**
# (a) x es incomparable con exactamente un elemento de P
# (b) F(x) es incomparable con exactamente un elemento de P

# %% [markdown]
# **Incomparable** => x/≤y y y/≤x
#
# a=>b
#
# Sea a∈P fijo tal que es incomparable con un elemento en (P,≤).Sea b∈P un elemento tal que a y be son incomparables.
#
# Lema**: Si x,y∈P son incomparables en (P,≤) <-> F(x),F(y)∈P′ son incomparables en (P′,≤′)
#
# Por el Lema ** F(A) y F(B) son incomparables.
# Supongamos que hay un elemento e′∈P′ tal que F(a) es incomparable con e′ en (P′,≤′). Probaremos que e′=F(b)
# Ya que F es sobre hay un c∈P tal que F(c)=e′
# O sea que F(A) y F(c) son incomparables, por el lema a y son incomparables en (P,≤). Pero por hipótesis b era el único incomparables, entonces concluimos b=c.
# Entonces F(b)=F(c) i.e e′=F(b)
#
# b=>a
#
# Notar que F{-1} es un iso de (P,≤) en (P′,≤′)

# %% [markdown]
# #**(10) Pruebe que si F : (P, ≤) → (P′, ≤′) un isomorfismo de posets, entonces son equivalentes:**
# (a) Cada elemento en (P, ≤) cubre exactamente dos elementos
# (b) Cada elemento en (P′, ≤′) cubre exactamente dos elementos

# %% [markdown]
# Def “b cubre a a” cuando: a<b y ∄z∈P con a<z<b.
#
# a=>b
#
# Tomamos un x,y,z ∈P tal que "x cubre a y" y "x cubre a z", o sea y≺x y z≺x por Lema 1.F tenemos entonces que F(y)≺′F(x) y F(z)≺′F(x).
# Ahora veamos por el absurdo que no existe otro elemento cubierto por F(x).
# Supongamos que existe un e′ en P′ talque e′≺′F(x) como F es una función sobreyectiva, entonces existe un e en P tal que F(e)=e′ y como F es un isomorfismo entonces es biyectiva y F^{-1} es un homomorfismo entonces F^{-1}(e′)≺F^{-1}(F(x)) o sea que e≺x pero esto es un absurdo pues x solo cubre a dos elementos por hipótesis.
#
# b=>a
#
# Similar pero al reves

# %% [markdown]
# #**(11) Si (P, ≤) es un reticulado par y m es un elemento maximal de (P, ≤) entonces m es un elemento maximo de (P, ≤).**

# %% [markdown]
# Sea m∈P maximal. Queremos probar que m es máximo, es decir ∀x∈P: x≤m.
# Tomemos un x∈P arbitrario. Como P es reticulado par, existe el supremo sup⁡{m,x}. Por el lema, m≤msx.
#
# Hay dos alternativas:
# 1. Si msx=m, entonces x≤m (porque x≤msx=m).
# 2. Si msx≠m, entonces m<msx, lo cual contradice la maximalidad de m (ya que maximal significa que no existe elemento estrictamente mayor que m). Por tanto esta alternativa no puede ocurrir.
#
# Entonces necesariamente msx=m y por tanto x≤m.
# Como x era arbitrario se concluye ∀x∈P:x≤m, es decir m es máximo.

# %% [markdown]
# #**(12) Si (P, ≤) es un reticulado par y m es un elemento minimal de (P, ≤) entonces m es un elemento minimo de (P, ≤).**

# %% [markdown]
# Sea m minimal. Queremos ∀x∈P: m≤x.
# Tomemos x∈P. Como P es reticulado par existe inf⁡{m,x}. Por el lema, mix≤m.
# Hay dos opciones:
# 1. Si mix=m, entonces m≤x (porque m=mix≤x).
# 2. Si mix≠m, entonces mix<m, lo que contradice la minimalidad de m (no puede existir nada estrictamente menor que un minimal). Por tanto esto no puede ocurrir.
#
# Luego necesariamente mix=m y por tanto m≤x.
# Como x era arbitrario,se concluye ∀x∈P:m≤x, es decir m es minimo.

# %% [markdown]
# #**(13) Sea (L, ≤) un reticulado par. Pruebe que x ≤ y si y solo si x i y = x,cualesquiera sean x, y ∈ L**

# %% [markdown]
# Sean x,y en P arbitrarios y fijos.
#
# =>
# Por definicion de infimo debo de probar que inf({x,y}) = x. Claramente x es cota inferior de {x,y} porque tenemos que x<=x y porque x<=y.
# Tomemos un z en P tal que también es cota inferior de {x,y} entonces por definicion z<=x. Pero ya probamos que inf ({x,y}) = x o sea que x i y = x
#
# <=
# Si x i y = x tengo que x es cota inferior de {x,y}. Entonces x<=x y x<=y. En particular x<=y

# %% [markdown]
# #**(14) Sea (L, ≤) un reticulado par. Pruebe que (x i y) i z = x i (y i z), cualesquiera sean x, y, z ∈ L**

# %% [markdown]
# Por Regla Igualdad para mostrar la igualdad podemos plantear estas dos desigualdades:
#  1. **(xiy)iz** ≤ xi(yiz)
#  2. xi(yiz) ≤ **(xiy)iz**.
#
# **Vamos con 1**
#
# (xiy)iz ≤ xi(yiz) usamos la Regla Ser ≤ que un Infimo: a≤bic es a≤b y a≤c
#
# a. (xiy)iz ≤ xiy ≤ x
#
# b.   (xiy)iz ≤ yiz
#
# b.1 (xiy)iz ≤ xiy ≤ y
#
# b.2 (xiy)iz ≤ z (pq el inf de z con algo es menor que z solo)
#
# **2 Analogo**

# %% [markdown]
# #**(15) Sea (L, ≤) un reticulado par. Pruebe que x ≤ z e y ≤ w implica x i y ≤ z i w, cualesquiera sean x, y, z, w ∈ L**

# %% [markdown]
# Supongamos x≤z y y≤w.
#
# Por x i y ≤ x, cualesquiera sean x, y ∈ L aplicado a x,y se tiene xiy≤x y xiy≤y.
#
# Aplicando transitividad con xiy≤x y x≤z obtenemos xiy≤z
#
# Análogamente, aplicando transitividad con xiy≤y y y≤w deducimos xiy≤w.
#
# Ahora, por la Regla Ser ≤ que un Infimo, de las dos desigualdades xiy≤z y xiy≤w se sigue xiy≤ziw
#
# Esto es exactamente lo que queríamos demostrar.

# %% [markdown]
# #**(16) Dado un poset (P, ≤) y a, b ∈ P diremos que b es base de a cuando se de que b < a y c ≤ b, para cada c ∈ P tal que c < a. Pruebe que si a, b ∈ P son tales que a es baseado por b, entonces si x ≱ a se tiene que a i x ≤ b.**

# %% [markdown]
# Pasando a limpio lo que hay que demostrar:
#
# Si a, b ∈ P son tales que a es baseado por b --> si a/≤x se tiene que aix ≤ b.
#
# Sea x en P tal que a/≤x, definio u:=aix. Como existe el ínfimo (reticulado) y por las props del mismo se tiene: u≤a y u≤x (1)
#
# Pero ¿u=a?, entonces por lema 2 tendríamos: a=u=aix⟹a≤x, lo cual contradice la hipótesis x≱ a. Por tanto la suposición  u=a es imposible y concluimos u≠a (2)
#
# Combinando (1) y (2) obtenemos u≤a y u≠a; por la definición de < esto significa u<a (3)
#
# Ahora usamos la hipótesis de base: como u<a, por la definición de base se cumple u≤b (4)
#
# Pero u=aix. Entonces (4) es exactamente la desigualdad buscada: aix≤b.

# %% [markdown]
# #**(17) Sea (P, ≤) un reticulado par y supongamos a, b ∈ P son tales que b tapa a a. Entonces si x ≰ a se tiene que a s x = b s x**

# %% [markdown]
# b tapa a a: a<b y b≤c, para cada c ∈ P tal que a<c.
#
# Vamos a demostrar que asx=bsx haciendo las desigualdades
#
# Tomemos un x∈P tal que x/≤a
#
# bsx≤asx
#
# Por regla de superar al supremo podemos probar que b≤asx y x≤asx
#
# b≤asx --> sabemos que a≤asx y x≤asx
# Pero a=asx?, supongamos que ocurre esto entonces a=asx esto se da si solo si x≤a o sea que se llega a una contradiccion con la que se había planteado desde un inicio.
# Entonces a≤asx y asx/=a entonces esta es la definicion de < por o que a<asx
#
# x≤asx --> trivial por lema
#
# Listo esta parte
#
# ----------------------------------------
# asx≤bsx
#
# Por regla de superar al supremo podemos probar que a≤bsx y x≤bsx
#
# x≤bsx --> trivial por lema
#
# a≤bsx --> como b≤bsx y b tapa a a obtenemos que a<b≤bsx o sea que a<bsx, pero recordemos la definicion de < a<=bsx y a/=bsx, entonces aca ya tenemos que a≤bsx.
#
# Entonces ahora asx≤bsx
#
# Como tenemos ambas desigualdades obtenemos nuestra igualdad

# %% [markdown]
# #**(18) Dado un poset (P, ≤) y a, b ∈ P diremos que b es base de a cuando se de que b < a y c ≤ b, para cada c ∈ P tal que c < a. Sea (P, ≤) un reticulado par y supongamos a, b ∈ P son tales que a es baseado por b. Entonces si x ≱ a se tiene que a i x = b i x.**

# %% [markdown]
# Probamos primero aix≤bix.
# Para esto podemos probar que aix≤b y aix≤x
#
# aix≤b
#
# Sea x en P tal que a/≤x u:=aix. Como existe el ínfimo (reticulado) y por las props del mismo se tiene: u≤a y u≤x (1)
#
# Pero ¿u=a?, entonces por lema 2 tendríamos: a=u=aix⟹a≤x, lo cual contradice la hipótesis x≱ a. Por tanto la suposición u=a es imposible y concluimos u≠a (2)
#
# Combinando (1) y (2) obtenemos u≤a y u≠a; por la definición de < esto significa u<a (3)
#
# Ahora usamos la hipótesis de base: como u<a, por la definición de base se cumple u≤b (4)
#
# Pero u=aix. Entonces (4) es exactamente la desigualdad buscada: aix≤b.
#
# aix≤x
#
# Por propiedades del infimo sabemos trivialmente que es verdad (Lema 1.2)
#
# -------------------------------------
# Ahora veamos bix≤aix. Nuevamente dividimos en dos la demostracion
#
# bix≤x
# Por propiedades del infimo sabemos trivialmente que es verdad (Lema 1.2)
#
# bix≤a
# Sabemos que bix≤b y como a es baseado por b ocurre que bix≤b<a o sea bix<a pero recordando la definicion de < tenemos que bix<=a y bix/=a entonces acá ya tenemos que bix≤a.
#
# Por lo que hemos concluido que bix≤aix

# %% [markdown]
# #**(19) Sea (L,s, i) un reticulado terna. Supongamos que x s (y i z) = (x s y) i (x s z), cualesquiera sean x, y, z ∈ L. Pruebe que entonces (L,s, i) es distributivo.**

# %% [markdown]
# Supongo que para todo x,y,z en L vale:x s (y i z) = (x s y) i (x s z). Ahora tomo a,b,c∈ L fijos y arbitrarios. Claramente cumplen esa propiedad y también pasa para aib.
#
# Tomo: x=aib y=a z=c
#
# Entonces (aib) s (aic) = ((aib) s a) i ((aib) s c)
#
# Usando conmutatividad
#
# = (a s (aib)) i (c s (aib))
#
# Usamos la propiedad de absorcion
#
# = a i (c s (aib))
#
# Aplicamos de nuevo la hipótesis (∗), pero con x=c,y=a,z=b.
#
# = a i ((csa) i (csb))
#
# Usamos asociacion de i
#
# = (a i (csa)) i (csb)
#
# Usamos conmutatividad de s
#
# = (a i (asc)) i (csb)
#
# Absorción de i
#
# = a i (csb)
#
# Conmutatividad de s
#
# = a i (bsc)
#
# Por lo que llegamos a: (aib) s (aic) = a i (bsc)
#
# Usando la reflexibilidad llegamos a que: a i (bsc) = (aib) s (aic)
#
# Como a,b,c arbitrarios entonces vale para todo elemento de L.

# %% [markdown]
# #**(20) Si F : (L,s, i) → (L′,s′, i′) es un homomorfismo biyectivo, entonces F es un isomorfismo.**

# %% [markdown]
# Un reticulado terna (L,s,i) es un conjunto L con dos operaciones binarias s e i que cumplen las identidades (I1)–(I7).
#
# Un homomorfismo de reticulados terna es una función F:(L,s,i)→(L′,s′,i′) tal que para todo x,y∈L: F(xsy)=F(x)s′F(y) , F(xiy)=F(x)i′F(y).
#
# Un isomorfismo es un homomorfismo biyectivo cuya inversa también es homomorfismo.
#
# **Proposición:** Si F:(L,s,i)→(L′,s′,i′) es un homomorfismo biyectivo, entonces F es un isomorfismo (es decir, su inversa F^{−1} también preserva s′ e i′).
#
# **Prueba:** Como F es biyectiva, existe la función inversa F^{−1}:L′→L.
#
# Queremos probar que, para todo y1,y2∈L′,F^{−1}(y1 s′ y2) = F^{−1}(y1) s F^{−1}(y2), y de forma análoga para i′.
#
# Sea y1,y2∈L′. Como F es sobreyectiva, existen x1,x2 ∈L tales que y1=F(x1),y2=F(x2).
#
# Entonces: F(F^{−1}(y1) s F^{−1}(y2)) = F(x1 s x2).
#
# Como F es homomorfismo: F(x1 s x2)=F(x1) s′ F(x2) = y1 s′ y2.
#
# Por lo tanto: F(F^{−1}(y1) s F^{−1}(y2)) = y1 s′ y2.
#
# Pero F es inyectiva, así que el único elemento de L cuya imagen es y1 s′
# y2 es precisamente F^{−1}(y1 s′y2).
#
# De aquí concluimos: F^{−1}(y1 s′ y2) = F^{−1}(y1) s F^{−1}(y2).
#
# Un razonamiento análogo vale para i′

# %% [markdown]
# #**(21) Si F : (L,s, i) → (L′,s′, i′) es un homomorfismo suryectivo y (L,s. i) es distributivo, entonces (L′,s′, i′) lo es. De un contraejemplo para el caso en que F no es suryectiva.**

# %% [markdown]
# (L,s,i) y (L′,s′,i′) son reticulados terna.
#
# F:L→L′ es homomorfismo y sobre
#
# (L,s,i) es distributivo, i.e. para todo x,y,z∈L
#
# x i (y s z)=(x i y) s (x i z)
#
# Queremos probar q para todo x′,y′,z′∈L′
#
# x′ i′ (y′ s′ z′)=(x′ i′ y′) s′ (x′ i′ z′) (distributivo).
#
# Sea x′,y′,z′∈L′ arbitrarios. Como F es sobreyectivo, existen x,y,z∈L tq
# F(x)=x′,F(y)=y′,F(z)=z′
#
# Empezamos con el lado izq de la igualdad y vamos a llegar al lado derecho usando las propiedades d F y L:
#
# x′ i′ (y′ s′ z′)
#
# = F(x) i′ (F(y) s′ F(z)) (porque x′=F(x), y′=F(y), z′=F(z))
#
# =F(x) i′ F(y s z) (por F(y s z)=F(y) s′ F(z))
#
# =F(x i (y s z))(por preservación de i por F)
#
# =F((x i y) s (x i z))(ya que L es distributivo)
#
# =F(x i y) s′ F(x i z) (por preservación de s por F)
#
# =(F(x) i′ F(y)) s′ (F(x) i′ F(z))(por preservación de i por F)
#
# =(x′ i′ y′) s′ (x′ i′ z′).
#
# Entonces probamos la igualdad, como x′,y′,z′∈L′ son elementos arbitrarios -> vale para todos los elementos de L′, o sea que (L′,s′,i′) es distributivo.

# %% [markdown]
# #**(22) Sean (L,s, i) y (L′,s′, i′) reticulados terna y sean (L, ≤) y (L′, ≤′) los posets asociados. Sea F : L → L′ una funcion. Pruebe que si F es un isomorfismode (L, ≤) en (L′, ≤′), entonces F es un isomorfismo de (L,s, i) en (L′,s′, i′).**

# %% [markdown]
# Hipótesis
#
# (L,s,i) y (L′,s′,i′) son reticulados terna; llamemos (L,≤) y (L′,≤′) a los posets asociados (por Dedekind).
#
# F:L→L′ es un isomorfismo de posets, es decir:
# *   F es biyectiva
# *   para todo x,y∈L x≤y ⟺ F(x)≤′F(y)
#
# Queremos probar que F es un isomorfismo de reticulados terna, es decir que además preserva las operaciones:
#
# F(x s y) = F(x) s′ F(y)
#
# F(x i y) = F(x) i′ F(y)
#
# para todo x,y∈L.
#
# Por teo de Dedekind sabemos que a s b = sup{a,b} en (L,<=). Entonces a <= a s b y b <= a s b
#
# Sea x,y∈L. Definamos z:=x s y en L. Queremos probar F(z)=F(x)s′F(y).
#
# 1. F(z) es cota superior de {F(x),F(y)}.
#
# Puesto que z es cota superior de {x,y} en L, x≤z y y≤z. Por la hipótesis de isomorfismo, F(x)≤′F(z) y F(y)≤′F(z). Por tanto F(z) es cota superior de {F(x),F(y)} en L′.
#
# 2. F(z) es la menor cota superior.
#
# Sea 𝑤′∈L′ cualquier cota superior de {F(x),F(y)}; es decir F(x)≤′w′ y F(y)≤′w′. Como F es biyectiva, existe w∈L con
# F(w)=w′. Usando la reflexión del orden (isomorfismo) obtenemos x≤w y y≤w. Entonces z=sup{x,y}≤w. Aplicando F y usando que F preserva el orden, F(z)≤′F(w)=w′.
#
# Esto muestra que cualquier cota superior 𝑤′ de {F(x),F(y)} domina a F(z). Por la definición de supremo, F(z) es la menor cota superior, es decir F(z)=sup_L′ {F(x),F(y)}.
#
# Por la definición de la operación s′ en el reticulado terna asociado a (𝐿′,≤′), sup_L′{F(x),F(y)} = F(x)s′F(y). Por tanto F(x s y) = F(z) = F(x) s′ F(y), como queríamos.
#
# La prueba para el ínfimo es dual.

# %% [markdown]
# #**(23) Sea (L,s, i) un reticulado terna y sea θ una congruencia de (L,s, i).**
# (a) Defina las operaciones˜s,˜ı
# (b) Defina ≤˜
# (c) Pruebe que (L/θ,˜s,˜ı) es un reticulado terna.

# %% [markdown]
# a) x/θ s˜ y/θ := (x s y)/θ y x/θ i˜ y/θ := (x i y)/θ
#
# b) Sea (L,s, i) un reticulado terna y sea θ una congruencia de (L,s, i). Entonces: x/θ ≤ ̃ y/θ sii yθ(x s y) cualesquiera sean x, y ∈ L.
#
# c)

# %% [markdown]
# #**(24) Sean (L,s, i) y (L′,s′, i′) reticulados terna y sea F : (L,s, i) → (L′,s′, i′) un homomorfismo.**
# (a) Pruebe que IF es un subuniverso de (L′,s′, i′).
# (b) Pruebe que ker(F) es una congruencia sobre (L,s, i)

# %% [markdown]
# Recordando definiciones:
#
# ImF:={F(x):x∈L}⊆L′ es la imagen de F.
#
# kerF:={(x,y)∈L×L:F(x)=F(y)} es el núcleo (kernel) de F.
#
# (a)
#
# Un subconjunto A⊆L′ es subuniverso si está cerrado por las operaciones: para todo u′,v′∈A se tiene u′ s′ v′∈A y u′ i′ v′∈A.
#
# Demostración: Sea u′,v′∈Im F.Por definición de imagen existen u,v∈L tales que u′=F(u) y v′=F(v). Entonces, usando que F es homomorfismo,
# u′ s′ v′ = F(u) s′ F(v) = F(u s v) ∈ Im F,
# y análogamente u′ i′ v′ = F(u) i′ F(v) = F(u i v) ∈ Im F.
#
# Por tanto Im F está cerrada bajo s′ e i′, es subuniverso de (L′,s′,i′).
#
# (b)
#
# Qué hay que probar. Una relación θ⊆LxL es congruencia si (i) es una relación de equivalencia (reflexiva, simétrica, transitiva) y (ii) es compatible con las operaciones: para todo (x,x′),(y,y′)∈θ, (x s y) θ (x′ s y′) y (x i y) θ (x′ i′ y′)
#
# Demostración.
# 1. ker F es relación de equivalencia.
# *   Reflexiva: Para todo x∈L, F(x)=F(x) así (x,x) ∈ ker F.
#
# *   Simétrica: Si (x,y) ∈ ker F entonces F(x)=F(y); así F(y)=F(x) y (y,x) ∈ ker F.
#
# *   Transitiva: Si (x,y),(y,z) ∈ ker F entonces F(x)=F(y) y F(y)=F(z), así F(x)=F(z) y (x,z) ∈ ker F.
#
# Por tanto ker F es equivalencia.
#
# 2. Compatibilidad con s e i.
#
# Sea (x,x′),(y,y′) ∈ ker F. Entonces F(x)=F(x′) y F(y)=F(y′). Aplicando que F es homomorfismo tenemos F(x s y) = F(x) s′ F(y) = F(x′) s′ F(y′)=F(x′ s y′).Por lo tanto F(x s y)=F(x′ s y′), es decir (x s y,x′ s y′) ∈ ker F.
#
# Análogamente,F(x i y)=F(x) i′ F(y) =F(x′) i′ F(y′) = F(x′ i y′),luego (x i y,x′ i y′) ∈ ker F.
#
# Así ker F es compatible con las operaciones, y por (1)+(2) es una congruencia sobre (L,s,i).

# %% [markdown]
# #**(27) Sea θ una congruencia del reticulado terna (L,s, i). Pruebe que**
# (a) si c ∈ L/θ, entonces c es un subuniverso de (L,s, i)
# (b) si c ∈ L/θ, entonces c es un subconjunto convexo de (L,s, i), es decir para cualesquiera x, y, z ∈ L, si se da que x, y ∈ c y x ≤ z ≤ y, entonces z ∈ c

# %% [markdown]
# a) Por hipotesis c ∈ L/θ ,es sub universo de (L,s,i)?
#
# Como c ∈ L/θ tenemos que c /=∅
#
# Veamos que c es cerrado bajo S: Sean x,y ∈ C y sea xsy=z. queremos ver que z están en C. Como x,y∈C y C ∈ L/θ tenemos que xθy. También sabemos que xθx. Ya que xθx y xθy y θ es una congruencia entonces (xsx)θ(xsy) (**)
#
# Como (xsx)=x y (xsy)=z y (**) tenemos que xθz.
#
# Luego como x ∈ C entonces z ∈ C.
#
# Para ver que es cerrado bajo el inifimo es totalmente análogo.
#
# b) Sea c ∈ L/θ queremos ver es que un subconjunto convexo de (L,s,i), i.e para cualesquiera x,y,z en L si x,y ∈ c y x <= z <=y, entonces z ∈ c
#
# Sean x,y ∈ c y z ∈ L, tal que x<=z<=y. veremos que z ∈ C.
#
# Ya que x,y ∈ c tenemos que xθy y tambien es obvio que zθz, y como θ es una congruencia tenemos que (xsz)θ(zsy) (**)
#
# Como sabemos por hipótesis que x<=z y z<=y, tenemos que (xsz)=z y (ysz)=y. Ahora usando (**) y que y ∈ c tenemos que z ∈ c.
